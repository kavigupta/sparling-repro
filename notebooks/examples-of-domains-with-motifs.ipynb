# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys, os

sys.path.insert(0, ".")
os.chdir("..")
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
import matplotlib.pyplot as plt
from pixel_art.display.display_domains import *

# %%
render_domains(show_motifs=False)
plt.savefig("output/demo.png", facecolor="white")
# Out:
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
render_domains(show_motifs=True)
plt.savefig("output/demo_with_dots.png", facecolor="white")
# Out:
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]
