# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys, os

sys.path.insert(0, ".")
os.chdir("..")
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import matplotlib.pyplot as plt
from pixel_art.analysis.confusion_plot import all_confusions

# %%
all_confusions()
plt.savefig("output/confusion_all.png")
plt.show()
