# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys, os

sys.path.insert(0, ".")
os.chdir("..")
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
import numpy as np

from pixel_art.analysis.pixel_art_experiment import all_pixel_art_errors_above_line
from pixel_art.analysis.main_experiment import load_sparsity_bars

# %%
errors = all_pixel_art_errors_above_line(0)

# %%
sparsity_bars = load_sparsity_bars()
print("Edit distance End-to-End accuracy:", f'{100 - errors["MT"]["e2e_edit"].mean():.2f}%')
print("Confusion accuracy               :", f'{100 - errors["MT"]["ce"].mean():.2f}%')
print("Sparsity                         :", f"{1 - sparsity_bars.right_above_line.sparsity_bar:.4%}")
print("Sparsity limit                   :", f"{1 - sparsity_bars.one_pixel_per_char.sparsity_bar:.4%}")
# Out:
# Edit distance End-to-End accuracy: 99.26%
# Confusion accuracy               : 98.84%
# Sparsity                         : 99.9950%
# Sparsity limit                   : 99.9955%
